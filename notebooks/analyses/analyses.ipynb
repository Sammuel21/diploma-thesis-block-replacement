# %% [markdown]
# ## Project Analyses
#
# this notebook serves as an index page for all the analyses/experiments performed in `notebooks/*`, the idea is to consolidate all ideas here.

# %% [markdown]
# ___

# %% [markdown]
# ### Importance Estimation

# %% [markdown]
# ### Budget Allocation

# %% [markdown]
# ### Operator Classes
#
# #### 1. Linear Layers
#
# #### 2. MLP expansion ratio
#
# #### 4. Hybrids
